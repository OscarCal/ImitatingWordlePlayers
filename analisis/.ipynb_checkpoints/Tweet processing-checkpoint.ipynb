# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from pathlib import Path
from datetime import date, timedelta
import re
import multiprocessing as mult

# %%
dataFrames = []

# %%
for i in range(196,516):
    dataFrames.append(pd.read_csv('../scraping_raw/' + str(i) +'.csv'))
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [152], in <cell line: 1>()
#       1 for i in range(196,516):
# ----> 2     dataFrames.append(pd.read_csv('../scraping_raw/' + str(i) +'.csv'))
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
tester = pd.read_csv('../scraping_raw/203.csv')

# %%
x = re.findall("((⬛|🟨|🟩|⬜){5})", tester['Text'][0])

# %%
tester['Text'][0]
# Out:
# 'Wordle 203 1/6\n\n🟩🟩🟩🟩🟩'

# %%
x
# Out:
# [('🟩🟩🟩🟩🟩', '🟩')]

# %%
x = re.findall("[⬛🟨🟩⬜]{5}", tester['Text'][10000])

# %%
x
# Out:
# ['⬛⬛🟩⬛⬛', '⬛🟩🟩⬛⬛', '⬛🟩🟩🟩🟩', '🟩🟩🟩🟩🟩']

# %%
tester['Text'][10000]
# Out:
# 'Wordle 203 4/6\n\n⬛⬛🟩⬛⬛\n⬛🟩🟩⬛⬛\n⬛🟩🟩🟩🟩\n🟩🟩🟩🟩🟩 \n\nYes…I’ve discovered this daily joy.'

# %%
tester['processed_text'] = tester['Text'].apply(lambda x: re.findall("[⬛🟨🟩⬜]{5}", x))

# %%
tester.head()
# Out:
#    Unnamed: 0  Game Trial                   Datetime             Tweet Id  \
# 0           0   203     1  2022-01-08 23:53:02+00:00  1479964391839834119
# 1           1   203     1  2022-01-08 23:49:28+00:00  1479963495806427136
# 2           2   203     1  2022-01-08 23:29:51+00:00  1479958559467126784
# 3           3   203     1  2022-01-08 23:24:13+00:00  1479957142337585154
# 4           4   203     1  2022-01-08 23:17:06+00:00  1479955350111596545
#
#                                                 Text        Username  \
# 0                            Wordle 203 1/6\n\n🟩🟩🟩🟩🟩      danielebel
# 1  Wordle 203 1/6\n\n🟩🟩🟩🟩🟩\n\nRandomly guessing a...   glamdring1999
# 2  First time Wordling.\nTime to quit.\n\nWordle ...       Axialmatt
# 3  Wordle 203 1/6\n\n🟩🟩🟩🟩🟩  \n\n🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️🤷‍♂️         _yaowu_
# 4                            Wordle 203 1/6\n\n🟩🟩🟩🟩🟩  sagitariusslut
#
#                                                  URL processed_text
# ...

# %%
tester['proc_length'] = tester['processed_text'].str.len()

# %%
tester['Trial'] = tester['Trial'].apply(lambda x: 6 if x == 'X' else int(x))

# %%
tester = tester.loc[tester['proc_length'] == tester['Trial']]

# %%
tester
# Out:
#        Unnamed: 0  Game  Trial                   Datetime  \
# 0               0   203      1  2022-01-08 23:53:02+00:00
# 1               1   203      1  2022-01-08 23:49:28+00:00
# 2               2   203      1  2022-01-08 23:29:51+00:00
# 3               3   203      1  2022-01-08 23:24:13+00:00
# 4               4   203      1  2022-01-08 23:17:06+00:00
# ...           ...   ...    ...                        ...
# 25576       25576   203      6  2022-01-08 00:05:40+00:00
# 25577       25577   203      6  2022-01-08 00:05:04+00:00
# 25578       25578   203      6  2022-01-08 00:03:59+00:00
# 25579       25579   203      6  2022-01-08 00:03:35+00:00
# 25580       25580   203      6  2022-01-08 00:01:11+00:00
#
#                   Tweet Id                                               Text  \
# 0      1479964391839834119                            Wordle 203 1/6\n\n🟩🟩🟩🟩🟩
# 1      1479963495806427136  Wordle 203 1/6\n\n🟩🟩🟩🟩🟩\n\nRandomly guessing a...
# ...

# %%
tester.loc[(tester['processed_text'].str[-1] == "🟩🟩🟩🟩🟩")]
# Out:
#        Unnamed: 0  Game  Trial                   Datetime  \
# 0               0   203      1  2022-01-08 23:53:02+00:00
# 1               1   203      1  2022-01-08 23:49:28+00:00
# 2               2   203      1  2022-01-08 23:29:51+00:00
# 3               3   203      1  2022-01-08 23:24:13+00:00
# 4               4   203      1  2022-01-08 23:17:06+00:00
# ...           ...   ...    ...                        ...
# 23953       23953   203      6  2022-01-08 13:31:00+00:00
# 23954       23954   203      6  2022-01-08 13:30:52+00:00
# 24188       24188   203      6  2022-01-08 19:11:59+00:00
# 24471       24471   203      6  2022-01-08 15:59:27+00:00
# 24508       24508   203      6  2022-01-08 15:39:17+00:00
#
#                   Tweet Id                                               Text  \
# 0      1479964391839834119                            Wordle 203 1/6\n\n🟩🟩🟩🟩🟩
# 1      1479963495806427136  Wordle 203 1/6\n\n🟩🟩🟩🟩🟩\n\nRandomly guessing a...
# ...

# %%
x = re.findall("[⬛🟨🟩⬜]{5}", tester['Text'][25384])
x
# Out:
# []
