# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
from pathlib import Path
from datetime import date, timedelta
import multiprocessing as mult

# %% [markdown]
# ## Testing

# %%
# Setting variables to be used below
maxTweets = 1000

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('Wordle 202, 4/6 since:2016-01-01 until:2022-05-10').get_items()):
    if i>maxTweets:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])

# %%
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-05-09 15:54:57+00:00  1523693011904851968
# 1    2022-05-07 09:21:03+00:00  1522869107485556736
# 2    2022-05-07 02:07:18+00:00  1522759950568951808
# 3    2022-05-06 17:21:24+00:00  1522627603982561280
# 4    2022-05-06 17:12:23+00:00  1522625336684384258
# ...                        ...                  ...
# 996  2022-01-08 04:07:28+00:00  1479666037377445888
# 997  2022-01-08 04:06:59+00:00  1479665915184648194
# 998  2022-01-08 04:06:47+00:00  1479665864743927809
# 999  2022-01-08 04:06:37+00:00  1479665821018468354
# 1000 2022-01-08 04:06:32+00:00  1479665800583815168
#
#                                                    Text       Username  \
# 0          Wordle 324 4/6\n\n🟨🟨⬛⬛⬛\n🟩⬛⬛🟨🟨\n🟩🟩⬛🟨🟩\n🟩🟩🟩🟩🟩      Big_E_202
# 1     Wordle 322 4/6\n\n⬜⬜🟨⬜⬜\n🟨🟨⬜🟨⬜\n🟩⬜🟨🟨⬜\n🟩🟩🟩🟩🟩\n...   Charlene_202
# 2     #한글 #워들 #Korean #Wordle https://t.co/AuRr3Ixhz...  hanahegies101
# 3     #한글 #워들 #Korean #Wordle https://t.co/tj4JF6Qqo...   chorong_0321
# 4     #한글 #워들 #Korean #Wordle https://t.co/wTAP0pz6m...        uky5124
# ...                                                 ...            ...
# 996   Wordle 202 4/6. Ok I’m hooked on this.  \n\n⬛⬛...  Purefidelityx
# 997        Wordle 202 4/6\n\n⬛⬛⬛⬛⬛\n⬛🟨⬛🟨🟨\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩🟩         puddor
# 998   Got on this bandwagon and it's fun! \n\nWordle...     maryhalton
# 999        Wordle 202 4/6\n\n🟩⬛⬛⬛⬛\n🟩🟨⬛⬛⬛\n🟩🟩⬛🟩⬛\n🟩🟩🟩🟩🟩      JLuna2124
# 1000       Wordle 202 4/6\n\n⬛⬛⬛⬛🟨\n⬛⬛🟩⬛⬛\n🟩🟩🟩⬛🟩\n🟩🟩🟩🟩🟩       gemsloop
#
#                                                     URL
# 0     https://twitter.com/Big_E_202/status/152369301...
# 1     https://twitter.com/Charlene_202/status/152286...
# 2     https://twitter.com/hanahegies101/status/15227...
# 3     https://twitter.com/chorong_0321/status/152262...
# 4     https://twitter.com/uky5124/status/15226253366...
# ...                                                 ...
# 996   https://twitter.com/Purefidelityx/status/14796...
# 997   https://twitter.com/puddor/status/147966591518...
# 998   https://twitter.com/maryhalton/status/14796658...
# 999   https://twitter.com/JLuna2124/status/147966582...
# 1000  https://twitter.com/gemsloop/status/1479665800...
#
# [1001 rows x 5 columns]

# %%
tweets_df2['Text'][996]
# Out:
# 'Wordle 202 4/6. Ok I’m hooked on this.  \n\n⬛⬛⬛⬛⬛\n⬛🟨🟨⬛⬛\n🟩⬛🟩🟩🟩\n🟩🟩🟩🟩🟩'

# %% [markdown]
# ## Tweet recovery

# %% [markdown]
# #### Format
# Wordle 510 X/6
#
# ⬜⬜🟨⬜🟨
# 🟨⬜🟨⬜⬜
# ⬜🟨🟨⬜⬜
# 🟨⬜⬜⬜🟨
# ⬜⬜⬜⬜🟨
# ⬜⬜⬜⬜⬜

# %%
maxTweets_per_trial = 100
maxTweets_per_word = 7000
tweets_list2 = []

for game in range(1,11):
    for trial in range(1,7):
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+ str(game)+' '+ str(trial)+
                                                                '/6"'+' since:2021-06-19 until:2022-11-11').get_items()):
            if i>maxTweets_per_trial:
                break
            tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url, game, trial])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [68], in <cell line: 5>()
#       5 for game in range(1,11):
#       6     for trial in range(1,7):
# ----> 7         for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+ str(game)+' '+ str(trial)+
#       8                                                                 '/6"'+' since:2021-06-19 until:2022-11-11').get_items()):
#       9             if i>maxTweets_per_trial:
#      10                 break
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\snscrape\modules\twitter.py:680, in TwitterSearchScraper.get_items(self)
#     677 	del params['tweet_search_mode']
#     678 	del paginationParams['tweet_search_mode']
# --> 680 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', params, paginationParams, cursor = self._cursor):
#     681 	yield from self._instructions_to_tweets(obj)
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\snscrape\modules\twitter.py:369, in _TwitterAPIScraper._iter_api_data(self, endpoint, params, paginationParams, cursor, direction)
#     367 while True:
#     368 	_logger.info(f'Retrieving scroll page {cursor}')
# --> 369 	obj = self._get_api_data(endpoint, reqParams)
#     370 	yield obj
#     372 	# No data format test, just a hard and loud crash if anything's wrong :-)
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\snscrape\modules\twitter.py:339, in _TwitterAPIScraper._get_api_data(self, endpoint, params)
#     337 def _get_api_data(self, endpoint, params):
#     338 	self._ensure_guest_token()
# --> 339 	r = self._get(endpoint, params = params, headers = self._apiHeaders, responseOkCallback = self._check_api_response)
#     340 	try:
#     341 		obj = r.json()
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\snscrape\base.py:216, in Scraper._get(self, *args, **kwargs)
#     215 def _get(self, *args, **kwargs):
# --> 216 	return self._request('GET', *args, **kwargs)
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\snscrape\base.py:173, in Scraper._request(self, method, url, params, data, headers, timeout, responseOkCallback, allowRedirects)
#     171 	logger.debug(f'... with data: {data!r}')
#     172 try:
# --> 173 	r = self._session.send(req, allow_redirects = allowRedirects, timeout = timeout)
#     174 except requests.exceptions.RequestException as exc:
#     175 	if attempt < self._retries:
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\requests\sessions.py:701, in Session.send(self, request, **kwargs)
#     698 start = preferred_clock()
#     700 # Send the request
# --> 701 r = adapter.send(request, **kwargs)
#     703 # Total elapsed time of the request (approximately)
#     704 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\requests\adapters.py:489, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     487 try:
#     488     if not chunked:
# --> 489         resp = conn.urlopen(
#     490             method=request.method,
#     491             url=url,
#     492             body=request.body,
#     493             headers=request.headers,
#     494             redirect=False,
#     495             assert_same_host=False,
#     496             preload_content=False,
#     497             decode_content=False,
#     498             retries=self.max_retries,
#     499             timeout=timeout,
#     500         )
#     502     # Send the request.
#     503     else:
#     504         if hasattr(conn, "proxy_pool"):
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     700     self._prepare_proxy(conn)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#     717 response_conn = conn if not release_conn else None
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\urllib3\connectionpool.py:386, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     384 # Trigger any extra validation we need to do.
#     385 try:
# --> 386     self._validate_conn(conn)
#     387 except (SocketTimeout, BaseSSLError) as e:
#     388     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#     389     self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\urllib3\connectionpool.py:1042, in HTTPSConnectionPool._validate_conn(self, conn)
#    1040 # Force connect early to allow us to validate the connection.
#    1041 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1042     conn.connect()
#    1044 if not conn.is_verified:
#    1045     warnings.warn(
#    1046         (
#    1047             "Unverified HTTPS request is being made to host '%s'. "
#    (...)
#    1052         InsecureRequestWarning,
#    1053     )
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\urllib3\connection.py:358, in HTTPSConnection.connect(self)
#     356 def connect(self):
#     357     # Add certificate verification
# --> 358     self.sock = conn = self._new_conn()
#     359     hostname = self.host
#     360     tls_in_tls = False
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     171     extra_kw["socket_options"] = self.socket_options
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#     179     raise ConnectTimeoutError(
#     180         self,
#     181         "Connection to %s timed out. (connect timeout=%s)"
#     182         % (self.host, self.timeout),
#     183     )
#
# File ~\anaconda3\envs\tfginfo\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      83     if source_address:
#      84         sock.bind(source_address)
# ---> 85     sock.connect(sa)
#      86     return sock
#      88 except socket.error as e:
#
# KeyboardInterrupt:

# %%
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'URL', 'game', 'trial'])
tweets_df2

# %%
# Setting variables to be used below
maxTweets = 1000

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle 206 4/6"'+' lang:en since:2022-01-11 until:2022-01-12').get_items()):
    if i>maxTweets:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])

# %%
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-01-11 23:59:58+00:00  1481053302670381060
# 1    2022-01-11 23:59:47+00:00  1481053254549180422
# 2    2022-01-11 23:59:43+00:00  1481053238057127937
# 3    2022-01-11 23:59:39+00:00  1481053223305846785
# 4    2022-01-11 23:59:37+00:00  1481053212501323781
# ...                        ...                  ...
# 996  2022-01-11 22:34:42+00:00  1481031842652475397
# 997  2022-01-11 22:34:39+00:00  1481031830560292865
# 998  2022-01-11 22:34:35+00:00  1481031813992755202
# 999  2022-01-11 22:34:33+00:00  1481031807491584001
# 1000 2022-01-11 22:34:32+00:00  1481031803704156162
#
#                                                    Text       Username  \
# 0          Wordle 206 4/6\n\n⬜⬜⬜⬜⬜\n🟩⬜⬜🟨⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩🟩🟩   ChrisMcLough
# 1          Wordle 206 4/6\n\n⬛🟩⬛⬛⬛\n⬛🟩⬛⬛⬛\n⬛🟩⬛⬛🟨\n🟩🟩🟩🟩🟩     prime_maia
# 2     Finally. Wordle 206 4/6\n\n🟨⬛🟨🟨⬛\n🟩🟨⬛⬛⬛\n🟩🟩🟩⬛⬛...  Readerleader5
# 3     i get it\n\nWordle 206 4/6\n\n⬜⬜🟨⬜⬜\n🟨🟨⬜⬜⬜\n⬜⬜...     melliferan
# 4     Wordle 206 4/6\n\n⬜⬜⬜⬜⬜\n⬜⬜🟩⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩🟩🟩\n...    TomBrevoort
# ...                                                 ...            ...
# 996    Ok? Wordle 206 4/6\n\n⬜🟩🟨⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩🟩🟩            acr
# 997        Wordle 206 4/6\n\n⬜⬜⬜⬜⬜\n⬜🟩🟩⬜⬜\n⬜🟩🟩⬜⬜\n🟩🟩🟩🟩🟩  Takashi_Gould
# 998   I hate trends…\n\nWordle 206 4/6\n\n⬜⬜🟨⬜⬜\n⬜⬜⬜...   jonnygodbold
# 999        Wordle 206 4/6\n\n⬜⬜⬜🟨🟨\n🟨⬜🟩🟨⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩🟩🟩    LongReacher
# 1000       Wordle 206 4/6\n\n⬜🟩⬜⬜⬜\n⬜🟩🟩⬜⬜\n⬜🟩🟩🟩⬜\n🟩🟩🟩🟩🟩  Thomas_Chanzy
#
#                                                     URL
# 0     https://twitter.com/ChrisMcLough/status/148105...
# 1     https://twitter.com/prime_maia/status/14810532...
# 2     https://twitter.com/Readerleader5/status/14810...
# 3     https://twitter.com/melliferan/status/14810532...
# 4     https://twitter.com/TomBrevoort/status/1481053...
# ...                                                 ...
# 996   https://twitter.com/acr/status/148103184265247...
# 997   https://twitter.com/Takashi_Gould/status/14810...
# 998   https://twitter.com/jonnygodbold/status/148103...
# 999   https://twitter.com/LongReacher/status/1481031...
# 1000  https://twitter.com/Thomas_Chanzy/status/14810...
#
# [1001 rows x 5 columns]

# %%
tweets_df2['URL'][998]
# Out:
# 'https://twitter.com/kegill/status/1481031923342331904'

# %%
# Setting variables to be used below
maxTweets = 3000

# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle 206 5/6"'+' lang:en since:2022-01-11 until:2022-01-12').get_items()):
    if i>maxTweets:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
tweets_df2
# Out:
#                       Datetime             Tweet Id  \
# 0    2022-01-11 23:59:56+00:00  1481053294474981378
# 1    2022-01-11 23:59:46+00:00  1481053249696411654
# 2    2022-01-11 23:58:44+00:00  1481052990656102406
# 3    2022-01-11 23:58:38+00:00  1481052966048399360
# 4    2022-01-11 23:58:34+00:00  1481052949388603392
# ...                        ...                  ...
# 2996 2022-01-11 17:38:26+00:00  1480957284259971074
# 2997 2022-01-11 17:38:18+00:00  1480957250583908365
# 2998 2022-01-11 17:38:13+00:00  1480957231344459781
# 2999 2022-01-11 17:38:12+00:00  1480957228383293440
# 3000 2022-01-11 17:38:12+00:00  1480957227284373505
#
#                                                    Text         Username  \
# 0     Wordle 206 5/6\n\n⬜⬜⬜🟨⬜\n🟨⬜⬜⬜⬜\n⬜🟩🟩🟩⬜\n⬜🟩🟩🟩⬜\n...          hhikida
# 1     Wordle 206 5/6\n\n⬜🟨⬜🟨⬜\n⬜⬜🟩🟩🟩\n⬜⬜🟩🟩🟩\n⬜🟩🟩🟩🟩\n...        mallorrrr
# 2     Wordle 206 5/6\n\n⬜⬜⬜⬜🟨\n⬜🟩⬜⬜⬜\n⬜🟩⬜⬜⬜\n⬜🟩🟩🟩🟨\n...         belpepsi
# 3     @icravechaos @samwarrren Wordle 206 5/6\n\n⬜⬜🟨...          srhckhn
# 4     Wordle 206 5/6*\n\n⬛⬛⬛🟨⬛\n⬛🟩⬛⬛⬛\n⬛🟩🟩⬛🟩\n⬛🟩🟩🟩🟩\...         Snikerop
# ...                                                 ...              ...
# 2996  Wordle 206 5/6\n\n⬛🟩⬛🟨🟨\n🟨🟨🟨⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩🟩⬛⬛\n...          ryanf07
# 2997  Wordle 206 5/6\n\n🟩⬜🟩⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩⬜⬜\n🟩🟩🟩⬜⬜\n...         smbrown5
# 2998  Wordle 206 5/6\n\n⬜⬜⬜⬜🟨\n🟨⬜⬜⬜⬜\n⬜🟩🟩⬜⬜\n⬜🟩🟩🟩🟩\n...      Lakerbooker
# 2999  Wordle 206 5/6\n\n⬛⬛🟨⬛⬛\n⬛⬛🟩🟨🟩\n⬛🟩🟩⬛🟩\n⬛🟩🟩⬛🟩\n...  wordofdaplourde
# 3000  @Lateralusian @cmclymer Is it the same word fo...       MannyD1990
#
#                                                     URL
# 0     https://twitter.com/hhikida/status/14810532944...
# 1     https://twitter.com/mallorrrr/status/148105324...
# 2     https://twitter.com/belpepsi/status/1481052990...
# 3     https://twitter.com/srhckhn/status/14810529660...
# 4     https://twitter.com/Snikerop/status/1481052949...
# ...                                                 ...
# 2996  https://twitter.com/ryanf07/status/14809572842...
# 2997  https://twitter.com/smbrown5/status/1480957250...
# 2998  https://twitter.com/Lakerbooker/status/1480957...
# 2999  https://twitter.com/wordofdaplourde/status/148...
# 3000  https://twitter.com/MannyD1990/status/14809572...
#
# [3001 rows x 5 columns]

# %%
tweets_df2['URL'][449]
# Out:
# 'https://twitter.com/BookwormBecky/status/1481030298582274049'

# %% [markdown]
# ## Batches

# %%
today = date.today()
today = today + timedelta(days = 1)
str(today)
# Out:
# '2022-11-18'

# %% [markdown]
# We will start by defining the various constants that we will use in our scaping.

# %%
maxtweets_per_trial = 5000

# %% [markdown]
# Now we will start working with the batches.

# %%
# Creating list to append tweet data to
tweets_list2 = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle 196 X/6"'+' lang:en since:2022-01-01 until:2022-01-02').get_items()):
    if i>maxtweets_per_trial:
        break
    tweets_list2.append([tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])

# %%
# Creating a dataframe from the tweets list above
tweets_df2 = pd.DataFrame(tweets_list2, columns=['Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
tweets_df2
# Out:
#                      Datetime             Tweet Id  \
# 0   2022-01-01 23:59:18+00:00  1477429254321098755
# 1   2022-01-01 23:58:27+00:00  1477429041124675584
# 2   2022-01-01 23:54:07+00:00  1477427949330583552
# 3   2022-01-01 23:45:40+00:00  1477425826199179270
# 4   2022-01-01 23:45:15+00:00  1477425721588867073
# ..                        ...                  ...
# 275 2022-01-01 00:44:41+00:00  1477078286769532930
# 276 2022-01-01 00:27:52+00:00  1477074054750236674
# 277 2022-01-01 00:22:46+00:00  1477072772186656768
# 278 2022-01-01 00:11:26+00:00  1477069922845052928
# 279 2022-01-01 00:07:08+00:00  1477068839489785859
#
#                                                   Text       Username  \
# 0    @markhumphries F^^^ yes!!!!\n\nWordle 196 X/6\...      OzStomper
# 1    Wordle 196 X/6\n\nI thought I had tried the co...    AaronLessis
# 2    What the hell is that word? \nWordle 196 X/6\n...  ThomasKuzma91
# 3    ugh ok y'all got me. i'm doing the dang emoji ...     starboots_
# 4    Wordle 196 X/6\n\n⬛⬛⬛🟨🟨\n🟨⬛🟨⬛⬛\n🟨⬛⬛🟨🟨\n🟩🟩⬛⬛🟩\n...   ninalasvegas
# ..                                                 ...            ...
# 275  Well this was shite\n\nWordle 196 X/6\n\n⬛🟦⬛⬛⬛...   Ayy_Lmao_Kay
# 276  ⬜⬜⬜⬜⬜\n⬜⬜⬜🟨⬜\n🟨⬜⬜⬜⬜\n⬜⬜⬜🟨⬜\n⬜🟨🟨⬜⬜\n⬜🟨🟨🟨⬜\n\nWo...     smoonjuice
# 277  Wordle 196 X/6\n\n⬛⬛⬛🟨🟨\n🟩⬛⬛🟩🟨\n🟩🟩⬛🟩⬛\n🟩🟩⬛🟩⬛\n...       IanMayor
# 278  Wordle 196 X/6\n\n⬛🟨⬛🟨🟨\n🟨🟩🟨⬛⬛\n🟩🟩⬛⬛🟩\n🟩🟩⬛⬛🟩\n...       HotCyder
# 279  Wordle 196 X/6\n\n⬛🟩⬛🟨⬛\n⬛🟩⬛⬛🟩\n⬛🟩⬛⬛🟩\n⬛⬛⬛🟨🟩\n...      SickMitch
#
#                                                    URL
# 0    https://twitter.com/OzStomper/status/147742925...
# 1    https://twitter.com/AaronLessis/status/1477429...
# 2    https://twitter.com/ThomasKuzma91/status/14774...
# 3    https://twitter.com/starboots_/status/14774258...
# 4    https://twitter.com/ninalasvegas/status/147742...
# ..                                                 ...
# 275  https://twitter.com/Ayy_Lmao_Kay/status/147707...
# 276  https://twitter.com/smoonjuice/status/14770740...
# 277  https://twitter.com/IanMayor/status/1477072772...
# 278  https://twitter.com/HotCyder/status/1477069922...
# 279  https://twitter.com/SickMitch/status/147706883...
#
# [280 rows x 5 columns]

# %%
maxtweets_per_trial = 5000
ini_date = date(2022,1,1)
for game in range(196, 197):
    tweets_list2 = []
    for trials in range(1,7):
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' '+str(trials)+'/6"'
                                                                +' lang:en since:'+str(ini_date)
                                                                +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
            if i>maxtweets_per_trial:
                break
            tweets_list2.append([game , trials ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
    for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' X/6"'
                                                                +' lang:en since:'+str(ini_date)
                                                                +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
            if i>maxtweets_per_trial:
                break
            tweets_list2.append([game , 'X' ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
    ini_date = ini_date + timedelta(days=1)
    tweets_df2 = pd.DataFrame(tweets_list2, columns=['Game', 'Trial' ,'Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
    tweets_df2.to_csv('../scraping_raw/' + str(game) + '.csv')

# %%
tweets_df2
# Out:
#       Game Trial                  Datetime             Tweet Id  \
# 0      196     1 2022-01-01 23:49:38+00:00  1477426821763268611
# 1      196     1 2022-01-01 23:33:35+00:00  1477422784217112578
# 2      196     1 2022-01-01 20:25:45+00:00  1477375513580621825
# 3      196     1 2022-01-01 20:18:26+00:00  1477373674034327554
# 4      196     1 2022-01-01 19:15:18+00:00  1477357786061099011
# ...    ...   ...                       ...                  ...
# 9302   196     X 2022-01-01 00:44:41+00:00  1477078286769532930
# 9303   196     X 2022-01-01 00:27:52+00:00  1477074054750236674
# 9304   196     X 2022-01-01 00:22:46+00:00  1477072772186656768
# 9305   196     X 2022-01-01 00:11:26+00:00  1477069922845052928
# 9306   196     X 2022-01-01 00:07:08+00:00  1477068839489785859
#
#                                                    Text         Username  \
# 0     This is becoming tiresome: Wordle 196 1/6\n\n🟩...     adamhorsfall
# 1                               Wordle 196 1/6\n\n🟩🟩🟩🟩🟩     TheRealPembo
# 2     Saw a not-cryptic-enough spoiler, unfortunatel...           grenow
# 3     This is a goid start to 2022\n\nWordle 196 1/6...         Yummhh__
# 4                               Wordle 196 1/6\n\n🟩🟩🟩🟩🟩  TowerGuardGames
# ...                                                 ...              ...
# 9302  Well this was shite\n\nWordle 196 X/6\n\n⬛🟦⬛⬛⬛...     Ayy_Lmao_Kay
# 9303  ⬜⬜⬜⬜⬜\n⬜⬜⬜🟨⬜\n🟨⬜⬜⬜⬜\n⬜⬜⬜🟨⬜\n⬜🟨🟨⬜⬜\n⬜🟨🟨🟨⬜\n\nWo...       smoonjuice
# 9304  Wordle 196 X/6\n\n⬛⬛⬛🟨🟨\n🟩⬛⬛🟩🟨\n🟩🟩⬛🟩⬛\n🟩🟩⬛🟩⬛\n...         IanMayor
# 9305  Wordle 196 X/6\n\n⬛🟨⬛🟨🟨\n🟨🟩🟨⬛⬛\n🟩🟩⬛⬛🟩\n🟩🟩⬛⬛🟩\n...         HotCyder
# 9306  Wordle 196 X/6\n\n⬛🟩⬛🟨⬛\n⬛🟩⬛⬛🟩\n⬛🟩⬛⬛🟩\n⬛⬛⬛🟨🟩\n...        SickMitch
#
#                                                     URL
# 0     https://twitter.com/adamhorsfall/status/147742...
# 1     https://twitter.com/TheRealPembo/status/147742...
# 2     https://twitter.com/grenow/status/147737551358...
# 3     https://twitter.com/Yummhh__/status/1477373674...
# 4     https://twitter.com/TowerGuardGames/status/147...
# ...                                                 ...
# 9302  https://twitter.com/Ayy_Lmao_Kay/status/147707...
# 9303  https://twitter.com/smoonjuice/status/14770740...
# 9304  https://twitter.com/IanMayor/status/1477072772...
# 9305  https://twitter.com/HotCyder/status/1477069922...
# 9306  https://twitter.com/SickMitch/status/147706883...
#
# [9307 rows x 7 columns]

# %%
load_test_pd = pd.read_csv('../scraping_raw/196.csv')
load_test_pd
# Out:
#       Unnamed: 0  Game Trial                   Datetime             Tweet Id  \
# 0              0   196     1  2022-01-01 23:49:38+00:00  1477426821763268611
# 1              1   196     1  2022-01-01 23:33:35+00:00  1477422784217112578
# 2              2   196     1  2022-01-01 20:25:45+00:00  1477375513580621825
# 3              3   196     1  2022-01-01 20:18:26+00:00  1477373674034327554
# 4              4   196     1  2022-01-01 19:15:18+00:00  1477357786061099011
# ...          ...   ...   ...                        ...                  ...
# 9302        9302   196     X  2022-01-01 00:44:41+00:00  1477078286769532930
# 9303        9303   196     X  2022-01-01 00:27:52+00:00  1477074054750236674
# 9304        9304   196     X  2022-01-01 00:22:46+00:00  1477072772186656768
# 9305        9305   196     X  2022-01-01 00:11:26+00:00  1477069922845052928
# 9306        9306   196     X  2022-01-01 00:07:08+00:00  1477068839489785859
#
#                                                    Text         Username  \
# 0     This is becoming tiresome: Wordle 196 1/6\n\n🟩...     adamhorsfall
# 1                               Wordle 196 1/6\n\n🟩🟩🟩🟩🟩     TheRealPembo
# 2     Saw a not-cryptic-enough spoiler, unfortunatel...           grenow
# 3     This is a goid start to 2022\n\nWordle 196 1/6...         Yummhh__
# 4                               Wordle 196 1/6\n\n🟩🟩🟩🟩🟩  TowerGuardGames
# ...                                                 ...              ...
# 9302  Well this was shite\n\nWordle 196 X/6\n\n⬛🟦⬛⬛⬛...     Ayy_Lmao_Kay
# 9303  ⬜⬜⬜⬜⬜\n⬜⬜⬜🟨⬜\n🟨⬜⬜⬜⬜\n⬜⬜⬜🟨⬜\n⬜🟨🟨⬜⬜\n⬜🟨🟨🟨⬜\n\nWo...       smoonjuice
# 9304  Wordle 196 X/6\n\n⬛⬛⬛🟨🟨\n🟩⬛⬛🟩🟨\n🟩🟩⬛🟩⬛\n🟩🟩⬛🟩⬛\n...         IanMayor
# 9305  Wordle 196 X/6\n\n⬛🟨⬛🟨🟨\n🟨🟩🟨⬛⬛\n🟩🟩⬛⬛🟩\n🟩🟩⬛⬛🟩\n...         HotCyder
# 9306  Wordle 196 X/6\n\n⬛🟩⬛🟨⬛\n⬛🟩⬛⬛🟩\n⬛🟩⬛⬛🟩\n⬛⬛⬛🟨🟩\n...        SickMitch
#
#                                                     URL
# 0     https://twitter.com/adamhorsfall/status/147742...
# 1     https://twitter.com/TheRealPembo/status/147742...
# 2     https://twitter.com/grenow/status/147737551358...
# 3     https://twitter.com/Yummhh__/status/1477373674...
# 4     https://twitter.com/TowerGuardGames/status/147...
# ...                                                 ...
# 9302  https://twitter.com/Ayy_Lmao_Kay/status/147707...
# 9303  https://twitter.com/smoonjuice/status/14770740...
# 9304  https://twitter.com/IanMayor/status/1477072772...
# 9305  https://twitter.com/HotCyder/status/1477069922...
# 9306  https://twitter.com/SickMitch/status/147706883...
#
# [9307 rows x 8 columns]

# %% [markdown]
# Now that we can see that our function works we will split the task into 4 and use parallel computing to obtain the batches faster. In order to so, we have to move these functions into another python script.

# %%
def batch1():
    ini_date = date(2022,1,1)
    for game in range(196, 277):
        tweets_list2 = []
        for trials in range(1,7):
            for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' '+str(trials)+'/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , trials ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' X/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , 'X' ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        ini_date = ini_date + timedelta(days=1)
        tweets_df2 = pd.DataFrame(tweets_list2, columns=['Game', 'Trial' ,'Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
        tweets_df2.to_csv('../scraping_raw/' + str(game) + '.csv')

# %%
def batch2():
    ini_date = date(2022,3,23)
    for game in range(277, 358):
        tweets_list2 = []
        for trials in range(1,7):
            for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' '+str(trials)+'/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , trials ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' X/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , 'X' ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        ini_date = ini_date + timedelta(days=1)
        tweets_df2 = pd.DataFrame(tweets_list2, columns=['Game', 'Trial' ,'Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
        tweets_df2.to_csv('../scraping_raw/' + str(game) + '.csv')

# %%
def batch3():
    ini_date = date(2022,6,12)
    for game in range(358, 439):
        tweets_list2 = []
        for trials in range(1,7):
            for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' '+str(trials)+'/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , trials ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' X/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , 'X' ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        ini_date = ini_date + timedelta(days=1)
        tweets_df2 = pd.DataFrame(tweets_list2, columns=['Game', 'Trial' ,'Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
        tweets_df2.to_csv('../scraping_raw/' + str(game) + '.csv')

# %%
def batch4():
    ini_date = date(2022,9,1)
    for game in range(439, 516):
        tweets_list2 = []
        for trials in range(1,7):
            for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' '+str(trials)+'/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , trials ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper('"Wordle '+str(game)+' X/6"'
                                                                    +' lang:en since:'+str(ini_date)
                                                                    +' until:'+ str(ini_date + timedelta(days=1))).get_items()):
                if i>maxtweets_per_trial:
                    break
                tweets_list2.append([game , 'X' ,tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.url])
        ini_date = ini_date + timedelta(days=1)
        tweets_df2 = pd.DataFrame(tweets_list2, columns=['Game', 'Trial' ,'Datetime', 'Tweet Id', 'Text', 'Username', 'URL'])
        tweets_df2.to_csv('../scraping_raw/' + str(game) + '.csv')

# %%
import get_raw_tweets as get_raw

# %%
p0 = mult.Process(target = get_raw.batch1)
p1 = mult.Process(target = get_raw.batch2)
p2 = mult.Process(target = get_raw.batch3)

# %%
p0.start()
p1.start()
p2.start()
p0.join()
p1.join()
p2.join()

# %%
dataf = pd.read_csv("../scraping_raw/196.csv")

# %%
dataf['Text'][5000]
# Out:
# "@TieflingFuklock Wordle 196 5/6\n\n🟨🟨⬛⬛⬛\n⬛🟩⬛⬛⬛\n🟩🟩🟩⬛⬛\n🟩🟩🟩🟩⬛\n🟩🟩🟩🟩🟩\n\nI cheated for the final guess cause I legit couldn't think of any other words that worked. Interesting game though"

# %%
p0 = mult.Process(target = get_raw.batch1)
p1 = mult.Process(target = get_raw.batch2)

# %%
p0.start()
p1.start()
p0.join()
p1.join()
